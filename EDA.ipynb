# %%
#Pandas- Creating data frames
import pandas as pd
q = {'Company':['Audi','BMW','Renault','Honda','Maruti','Cheverlot','Mahindra'],'Origin_Country':['Switzerland','Germany','France','Japan','India','U.S.','India'],'Avg_Price':[10800000,12000000,1100030,1450000,1530000,1600000,700000]}
v = pd.DataFrame(q)
print(v)
print(type(v))
myvar = pd.Series(q)
myvar
# Out:
#      Company Origin_Country  Avg_Price
# 0       Audi    Switzerland   10800000
# 1        BMW        Germany   12000000
# 2    Renault         France    1100030
# 3      Honda          Japan    1450000
# 4     Maruti          India    1530000
# 5  Cheverlot           U.S.    1600000
# 6   Mahindra          India     700000
# <class 'pandas.core.frame.DataFrame'>
# Company           [Audi, BMW, Renault, Honda, Maruti, Cheverlot,...
# Origin_Country    [Switzerland, Germany, France, Japan, India, U...
# Avg_Price         [10800000, 12000000, 1100030, 1450000, 1530000...
# dtype: object

# %%
# EXPLORATORY DATA ANALYSIS- PRE MACHINE LEARNING CONCEPT
# Finding key and valuable INSIGHTS bassed on the available data and draw the conclusions
"""In this we are going to apply the concepts of EDA to a fruits_dataset and derieve conclusions by understanding the data"""
# Extracting the data directly from the URL
"""import pandas as pd
df = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230819%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230819T124946Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df"""
import pandas as pd
df1 = pd.read_csv("fruit_data_with_colors.txt",sep ='\t')
df1
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
#To understand the properties of the data retrieved-
print(df1.size)#total no.of rows and columns (59,7)
print(df1.shape)#total no.of elements in the dataframe
df1.info()
# Out:
# 413
# (59, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#SLICING - var[inclusive_index : exclusive_index]
#To retrieve the data in between slicing is used thus:
#e.g.: SLICE THE ABOVE DATAFRAME FROM ROW 23 TO 40
print(df1[23:41])
#to slice both rows and columns simaltaneously-
df1.iloc[23:41,0:2]
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 23            1      apple       cripps_pink   170    7.6     7.9         0.88
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# ...

# %%
#let us consider the column fruit_name, to know the exact number of unique fruits-
print(df1.fruit_name.nunique())
fname = df1['fruit_name'].unique()
fname
# Out:
# 4
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#Now to know the exact count of each unique fruit-
print(df1.groupby('fruit_name').size())
fsize = df1.groupby('fruit_name').size()
#Data Visualization
import matplotlib.pyplot as plt
plt.bar(fname,fsize, color = ['red','yellow','green','blue'])
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64
# <BarContainer object of 4 artists>

# %%
#Thus, we can arrive at conclusions much easier from above visualization
#Apples- Highest sale
#Orange- lowest sale
